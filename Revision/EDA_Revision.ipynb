# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Data set for Data science/titanic/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **UNIVARIANTE Analysis**

# %% [markdown]
# EDA Steps
#
# if categorical data
# 1. countplot
# 2. pie chart
#
# if numerical data
#
# hist plot
#
# dist plot
#
# box plot

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='Embarked'>

# %%
plt.hist(df['Age'],bins=50)
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# distplot humme yeh bhi batata hai ki hummare data me skewness hai ki nahi

# %%
sns.displot(df['Age'],kde=True)

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
print(df['Age'].max(),df['Age'].mean(),df['Age'].min())
# Out:
# 80.0 29.69911764705882 0.42

# %% [markdown]
# **Bivariate  & Multivariate Analysis**

# %%
titanic = pd.read_csv("/content/drive/MyDrive/Data set for Data science/titanic/train.csv")

# %%
tips = sns.load_dataset('tips')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# Numerical - Numerical : scatterplot
#
# Numerical - Categorical : Bar Plot , Box plot, Distplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style= tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.histplot(titanic[titanic['Survived']==0]['Age'],kde=True)
sns.histplot(titanic[titanic['Survived']==1]['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(titanic[titanic['Survived']==0]['Age'])
sns.kdeplot(titanic[titanic['Survived']==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Categorical - categorical : HeatMap, Cluster Map, Pairplot

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(titanic['Sex'],titanic['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
heatmap_data=pd.crosstab(titanic['Pclass'],titanic['Survived'])
sns.heatmap(heatmap_data)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Pclass').mean()['Survived']*100).plot(kind='bar')
# Out:
# <ipython-input-45-36fe98ce360d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (titanic.groupby('Pclass').mean()['Survived']*100).plot(kind='bar')
# <Axes: xlabel='Pclass'>

# %%
(titanic.groupby('Sex').mean()['Survived']*100)
# Out:
# <ipython-input-47-f71bcfd89f0e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (titanic.groupby('Sex').mean()['Survived']*100)
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Embarked').mean()['Survived']*100)
# Out:
# <ipython-input-48-de774dc4ad39>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (titanic.groupby('Embarked').mean()['Survived']*100)
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# this is dendographs , capturs hierachical relation

# %% [markdown]
# Pairplot : collection of scatter plot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# **Line Plot - (Numerical - Numerical)**
# Line plot tab use karna chaiye jab x axi me jo quantity hai woh time based entity , like Covid cases no , stocks prices data

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new=flights.groupby('year').sum().reset_index()
# Out:
# <ipython-input-58-a6a659e855c3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new=flights.groupby('year').sum().reset_index()

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# heat map me jab bahoot sarri value hoti hai tab dekhne me mazza aata hai

# %% [markdown]
# pivot me kya chige hoti hai ek values , ek index and column bas isi ka use karna hai

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# lighter shades means jyadda customer

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
